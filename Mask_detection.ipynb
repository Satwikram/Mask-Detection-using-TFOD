# %% [markdown]
# <a href="https://colab.research.google.com/github/Satwikram/Mask-Detection/blob/master/Mask_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==1.14.0
# Out:
# ...
#      |████████████████████████████████| 109.2MB 68kB/s
# ...
#      |████████████████████████████████| 491kB 42.3MB/s
# ...
#      |████████████████████████████████| 3.2MB 34.9MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# ...

# %%
# !dir
# Out:
# drive  sample_data

# %%
# %cd /content/drive/My Drive/corona_mask_detection/models/research
# Out:
# /content/drive/My Drive/corona_mask_detection/models/research

# %%
# !dir
# Out:
# a3c_blogpost			  lstm_object_detection
# adversarial_crypto		  marco
# adversarial_logit_pairing	  maskgan
# adversarial_text		  minigo
# adv_imagenet_models		  morph_net
# astronet			  namignizer
# attention_ocr			  nets
# audioset			  neural_gpu
# autoaugment			  neural_programmer
# autoencoder			  next_frame_prediction
# brain_coder			  nst_blogpost
# build				  object_detection
# cognitive_mapping_and_planning	  object_detection_Converted.py
# cognitive_planning		  object_detection.egg-info
# compression			  object_detection_tutorial.ipynb
# cvt_text			  pcl_rl
# deep_contextual_bandits		  ptn
# deeplab				  qa_kg
# deep_speech			  README.md
# delf				  real_nvp
# deployment			  rebar
# differential_privacy		  resnet
# dist				  sentiment_analysis
# domain_adaptation		  seq2species
# efficient-hrl			  setup.py
# faster_rcnn			  skip_thoughts
# fivo				  slim
# gan				  steve
# generate_tfrecord.py		  street
# global_objectives		  struct2depth
# im2txt				  swivel
# ...

# %%
# Training the model from 1000 epochs
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
